# %%
import cv2
import time
import random
import os


direc=r'C:\Users\Srinath\Eye\dataset\videos\Open'



labels = os.listdir(direc)



OPENED EYE DATASET

for i in labels:
    l=os.path.join(direc, i)
    video=cv2.VideoCapture(l)


    facedetect = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_default.xml')
    leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
    reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')

    eye_cascade = cv2.CascadeClassifier('haar cascade files\haarcascade_eye_tree_eyeglasses.xml')

    count=0
    while True:
      ret,frame=video.read()
      faces=facedetect.detectMultiScale(frame,1.1,4)
          #faces=facedetect.detectMultiScale(frame,1.1,4)
      gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

      left_eye = leye.detectMultiScale(gray)
      right_eye =  reye.detectMultiScale(gray)
      eye=eye_cascade.detectMultiScale(gray)


      for x,y,w,h in eye:


        r=random.randint(0,1000)
        k=random.randint(10,80)
        s=str(r)+str(k)

        #print(s)
        #FOR OWN DATASET_WITHOUT_MASK_START

        count+=1
        name='C:/Users/Srinath/Eye/dataset/open/'+s+'.jpg'
        print("Creating Images......."+name)
        cv2.imwrite(name,frame[y:y+h+20,x:x+w+20])
        
        
        #WITHOUT_MASK_END
'


        count+=1
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)

      cv2.imshow("WindowFrame",frame)
      cv2.waitKey(1)
      if count>200:
        break
    video.release()
    cv2.destroyAllWindows()
    

# #CLOSED EYE DATA

# direc1=r'C:\Users\Srinath\Eye\dataset\videos\Close'
# #labels1 = os.listdir(direc1)
# labels1=['WhatsApp Video 2021-09-20 at 11.10.mp4']
# for i in labels1:
#     l=os.path.join(direc1, i)
#     video=cv2.VideoCapture(l)


#     facedetect = cv2.CascadeClassifier('haar cascade files\haarcascade_frontalface_default.xml')
#     leye = cv2.CascadeClassifier('haar cascade files\haarcascade_lefteye_2splits.xml')
#     reye = cv2.CascadeClassifier('haar cascade files\haarcascade_righteye_2splits.xml')

#     eye_cascade = cv2.CascadeClassifier('haar cascade files\haarcascade_eye_tree_eyeglasses.xml')

#     count=0
#     while True:
#       ret,frame=video.read()
#       faces=facedetect.detectMultiScale(frame,1.1,4)
#           #faces=facedetect.detectMultiScale(frame,1.1,4)
#       gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#       left_eye = leye.detectMultiScale(gray)
#       right_eye =  reye.detectMultiScale(gray)
#       eye=eye_cascade.detectMultiScale(gray)


#       for x,y,w,h in eye:


#         r=random.randint(0,1000)
#         k=random.randint(10,80)
#         s=str(r)+str(k)

#         #print(s)
#         #FOR OWN DATASET_WITHOUT_MASK_START

#         count+=1
#         name='C:/Users/Srinath/Eye/dataset/close/'+s+'.jpg'
#         print("Creating Images......."+name)
#         cv2.imwrite(name,frame[y:y+h+20,x:x+w+20])
        


#         count+=1
#         cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)

#       cv2.imshow("WindowFrame",frame)
#       cv2.waitKey(1)
#       if count>200:
#         break
#     video.release()
#     cv2.destroyAllWindows()
# Out:
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/60742.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/80246.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/75379.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/15968.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/36579.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/50142.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/85323.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/51742.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/51822.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/49765.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/19856.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/89968.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/25222.jpg
# Creating Images.......C:/Users/Srinath/Eye/dataset/close/7756.jpg
# ...

# %%
|
